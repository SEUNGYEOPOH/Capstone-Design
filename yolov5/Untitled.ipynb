# %%
from tools.img_seg.models.unet import vgg_unet

model = vgg_unet(n_classes=50 ,  input_height=640, input_width=640  )

model.load_weights('./best_seg.h5')

# %%
out = model.predict_segmentation(
    inp="./video/cap/0.png",
    out_fname="./out.png"
)
# Out:
# 1/1 [==============================] - 3s 3s/step

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.imshow(out)

# %%
from IPython.display import Image

# %%
Image('./out.png')

# %%
ou = model.predict_segmentation(
    inp="./video/cap/0.png",
    out_fname="./out1.png" , overlay_img=True, show_legends=True,
    class_names = [ "Sky","Building", "Pole","Road","Pavement","Tree","SignSymbol", "Fence", "Car","Pedestrian", "Bicyclist"]
)
# Out:
# 1/1 [==============================] - 0s 30ms/step

# %%
Image('./out1.png')
